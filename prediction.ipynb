# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From c:\python_envs\global_env\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
word_index =imdb.get_word_index()
reverse_word_index={value:key for key,value in word_index.items()}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 3s 2us/step

# %%
model=load_model("simple_rnn_imdb.h5")
model.summary()
# Out:
# WARNING:tensorflow:From c:\python_envs\global_env\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 128)          1280000
#
#  simple_rnn_1 (SimpleRNN)    (None, 128)               32896
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Takes a review encoded as numbers

# Converts numbers → words using dictionary

# Joins words into a readable sentence

def decode_review(encoded_review):
    return " ".join([reverse_word_index.get(i-3,'?') for i in encoded_review])

# %%
# Raw text
# ↓
# Tokenized words
# ↓
# Numbers
# ↓
# Fixed-length padded sequence
# ↓
# Ready for neural network
from tensorflow.keras.preprocessing import sequence

def preprocess_text(text):
    words = text.lower().split()
    
    encoded_review = [
        (word_index[word] + 3) if word in word_index and word_index[word] < 10000 else 2
        for word in words
    ]
    
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    
    return padded_review

# %%
def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)
    prediction=model.predict(preprocessed_input)
    sentiment = "Positive" if prediction[0][0] > 0.5 else "Negative"
    if prediction[0][0] > 0.54 :
        sentiment="Positive"
    elif prediction[0][0]<0.48:
        sentiment="Negative"
    else :
        sentiment="Neutral"
    return sentiment,prediction[0][0]

# %%
text="not bad"
sentiment,score=predict_sentiment(text)
print(f"Review:{text}")
print(f"Sentiment:{sentiment}")
print(f"Prediction Score:{score}")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Review:not bad
# Sentiment:Negative
# Prediction Score:0.41435396671295166
